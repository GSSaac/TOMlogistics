# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import os
from tkinter import *

# %%
Dataset_name = 'TechLabsDataset.csv' 
Dataset = pd.read_csv(os.path.join('./Data/',Dataset_name), index_col = 0)

# %%
review_df = pd.DataFrame(Dataset[~Dataset['review_EN'].isnull()]['review_EN'], columns = ['review_EN'])
review_df['sentiment'] = np.nan
review_df['reviewer'] = np.nan
review_df.reset_index(inplace = True)
review_df
# Out:
#       index                                          review_EN  sentiment  \
# 0         3  Best employer ever. Worked there for approxima...        NaN
# 1         4  better place with very good people everything ...        NaN
# 2         5                                               Nice        NaN
# 3         6   Good firm. The staff are very welcoming and f...        NaN
# 4         7        Top company, and coffee, so recommended\n\n        NaN
# ...     ...                                                ...        ...
# 3393   8068   Untrustworthy people, they are good at lying....        NaN
# 3394   8069   Drives antisocial and overtakes right on the ...        NaN
# 3395   8070   In a word, toppers! Always think in possibili...        NaN
# 3396   8071                                  First service\n\n        NaN
# 3397   8076                                         Unique\n\n        NaN
#
#       reviewer
# 0          NaN
# 1          NaN
# 2          NaN
# ...

# %%
annotators = ['Katarzyna','Linh','Sifiso','Khalid','Giuseppina']
for a in annotators:
    review_df.to_csv('./Data/Annotations_'+a+'.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import os
from tkinter import *

# %%
Dataset_name = 'TechLabsDataset.csv' 
Dataset = pd.read_csv(os.path.join('./Data/',Dataset_name), index_col = 0)

# %%
review_df = pd.DataFrame(Dataset[~Dataset['review_EN'].isnull()]['review_EN'], columns = ['review_EN'])
review_df['sentiment'] = np.nan
review_df['reviewer'] = np.nan
review_df.reset_index(inplace = True)
review_df

# %%
review_df.to_csv('./Data/Annotations_Giuseppina.csv')

# %%
# Annotation_name = 'Annotations_Giuseppina.csv'
# review_df = pd.read_csv(os.path.join('./Data/',Annotation_name),index_col = 0)
# review_df.set_index('index',inplace = True)
# mask = ~review_df['review_EN'].isnull()

# rev_index = review_df[mask].index

# %%
from tkinter import *
from tkinter import filedialog as fd
import demoji
demoji.download_codes()

def find_replace_emo(text):
    all_emoji = demoji.findall(text)
    new_text = 'Emojis: \n'
    if len(all_emoji)>0:
        for i,j in enumerate(all_emoji):
            item = all_emoji[j]
            new_text = new_text+str(i+1)+' '+all_emoji[j]+'\n'
            text = text.replace(j,'_')
            text = text+'\n\n'+new_text
    else:
        text = text+'\n\n'+ new_text+'\n None'
    return text

def next_review():
    global review_df
    global rev_index
    if (var_sent.get()) and (var_emp.get()):
        review_df['sentiment'].loc[rev_index[window._my_hidden_value]] = var_sent.get()
        review_df['reviewer'].loc[rev_index[window._my_hidden_value]] = var_emp.get()
        window._my_hidden_value = window._my_hidden_value+1
        message_1.config(text='')
        txtfld.delete(1.0,END)
        text = review_df['review_EN'].loc[rev_index[window._my_hidden_value]]
        text = find_replace_emo(text)
        txtfld.insert(END, text)
        var_sent.set('')
        var_emp.set('')
        message_ld2.config(text=str(len(rev_index)-1)+' ('+str(np.round((len(rev_index)-1)/review_df.shape[0],2)*100)+"%)",
                       font=("Avenir", 12,'bold'))
        
    else:
        message_1.config(text='Message: Please, complete the annotation of current review before going to the Next',
                     fg='red',font=("Avenir", 12,'bold'))
        
def save_annot():
    global review_df
    global filename
    review_df.reset_index(inplace = True)
    review_df.to_csv(filename)
    message_2.config(text='Message: Annotations have been saved',
                 fg='green',font=("Avenir", 12,'bold'))
    window.destroy()
    
def load_annot():
    global review_df
    global rev_index
    global filename
    
    filetypes = (
        ('text files', '*.csv'),
    )

    filename = fd.askopenfilename(
        title='Open a file',
        initialdir='./Data/',
        filetypes=filetypes)
#     print(filename)
    review_df = pd.read_csv(filename,index_col = 0)
    #print(review_df.head())
    review_df.set_index('index',inplace = True)
    mask = review_df['reviewer'].isnull()

    rev_index = review_df[mask].index
#     print(mask)
    text = review_df['review_EN'].loc[rev_index[window._my_hidden_value]]
    text = find_replace_emo(text)
    txtfld.insert(END, text)
    
    message_ld1.config(text='Left: ',font=("Avenir", 12))
    message_ld2.config(text=str(len(rev_index))+' ('+str(np.round(len(rev_index)/review_df.shape[0],2)*100)+"%)",
                       font=("Avenir", 12,'bold'))



        
###################

window=Tk()
window.geometry("600x450+10+10")
# p1 = PhotoImage(file = './figures/bird.png')
# window.iconbitmap('./figures/favicon.ico')
window.title('© SAAC 2022  - TOM in Logistics: Annotation GUI - ')
# Setting icon of master window
# window.iconphoto(False, p1)
# window.iconbitmap('./figures/SAAClogo100.png')
window.resizable(False, False) 
window._my_hidden_value = 0

# Create a scrollbar
scrollbar = Scrollbar(window)
scrollbar.pack( side = RIGHT, fill = Y )
# title
lbl=Label(window, text="Reviews Annotation", fg='black', font=("Avenir", 16,'bold'))
lbl.place(x=10, y=10)


k = 50
# Create text widget and specify size.
txtfld = Text(window, height = 5, width = 70, wrap="word", bg = "lightgray", 
              yscrollcommand=scrollbar.set,padx = 20, pady = 20, font = ("Courier", 12))
# 
# txtfld.insert(INSERT, review_df.iloc[0])

# Insert text into the text widget

txtfld.pack( side = LEFT, fill = BOTH )

scrollbar.config(command=txtfld.yview)
scrollbar.pack(fill=Y)
# txtfld.see("end")
txtfld.place(x=10, y=k+50)

    
Load_bt = Button(window, text ="Load Annotation File", command = load_annot)
Load_bt.place(x = 10, y = k)

message_ld1 = Label(window, text ="")
message_ld1.place(x = 300, y = k)

message_ld2 = Label(window, text ="")
message_ld2.place(x = 350, y = k)

lbl=Label(window, text="Read the review (scroll text to see more)", fg='black', font=("Avenir", 12,'bold'))
lbl.place(x=10, y=k+29)




lbl=Label(window, text="Indicate if you think it is a positive/neutral/negative review", fg='black', 
          font=("Avenir", 12,'bold'))
lbl.place(x=10, y=k+160)

var_sent = StringVar()
Good = Radiobutton(window, text="Positive", variable=var_sent, value='Positive')
Good.place(x=20, y=k+190)
# Good.pack( anchor = window)
Neutral = Radiobutton(window, text="Neural", variable=var_sent, value='Neural')
Neutral.place(x=120, y=k+190)
# Neutral.pack( anchor = window)
Bad = Radiobutton(window, text="Negative", variable=var_sent, value='Negative')
Bad.place(x=220, y=k+190)
# Bad.pack( anchor = window)


lbl=Label(window, text="Indicate if you think the review was written by client/employee/unknown", 
          fg='black', font=("Avenir", 12,'bold'))
lbl.place(x=10, y=k+220)

var_emp = StringVar()
Client = Radiobutton(window, text="Client", variable=var_emp, value='Client')
Client.place(x=20, y=k+250)
Employee = Radiobutton(window, text="Employee", variable=var_emp, value='Employee')
Employee.place(x=120, y=k+250)
Unknown = Radiobutton(window, text="Undefined", variable=var_emp, value='Undefined')
Unknown.place(x=220, y=k+250)


next_bt = Button(window, text ="Go to Next Review >>>", command = next_review)
next_bt.place(x = 10, y = k+290)
# sub_bt = Button(top, text ="Summit your Annotation", command = helloCallBack)


message_1 = Label(window)
message_1.place(x = 10, y = k+320)


save_bt = Button(window, text ="Save Annotations", command = save_annot)
save_bt.place(x = 10, y = k+350)

message_2 = Label(window)
message_2.place(x = 150, y = k+350)

window.mainloop()
# Out:
# Downloading emoji data ...
# ... OK (Got response in 0.39 seconds)
# Writing emoji data to /Users/giu/.demoji/codes.json ...
# ... OK
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/tkinter/__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-33-bb8ca41b11fd>", line 33, in next_review
#     message_ld2.config(text=str(mask.shape[0])+' ('+str(np.round((len(rev_index)-1)/review_df.shape[0],2)*100)+"%)",
# NameError: name 'mask' is not defined

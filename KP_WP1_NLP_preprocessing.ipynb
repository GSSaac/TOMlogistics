# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

pd.set_option("display.max_columns", 500)
pd.set_option("display.max_rows", 500)
pd.set_option('display.max_colwidth', None)

df = pd.read_csv("D:/00_Coding/16_TechLabs/01_GroupProject/TOMlogistics/Data/TechLabsDataset.csv",index_col = 0)

# %%
df.tail(10)
# Out:
#                                name       type_company        lat       lon  \
# 8070                 L.H. Logistics   Trucking company  51.617957  4.736123
# 8071                 L.H. Logistics   Trucking company  51.617957  4.736123
# 8072                 L.H. Logistics   Trucking company  51.617957  4.736123
# 8073                 L.H. Logistics   Trucking company  51.617957  4.736123
# 8074  NLS Logistics & Services B.V.  Logistics service  51.437232  5.561307
# 8075            Van Thiel Logistics   Trucking company  51.827945  5.765815
# 8076  InTime Logistics & Consulting   Trucking company  52.049578  5.117079
# 8077  InTime Logistics & Consulting   Trucking company  52.049578  5.117079
# 8078  InTime Logistics & Consulting   Trucking company  52.049578  5.117079
# 8079    Same Day Delivery Logistics   Trucking company  51.875330  4.451959
#
#             city  avg_stars_num  n_reviews_num encoded_user  local_guide  \
# ...

# %%
dic = pd.read_csv('D:/00_Coding/16_TechLabs/01_GroupProject/TOMlogistics/Data/TechLabsDataset_Dictionary.csv',index_col = 0)

# %%
dic
# Out:
#                   variable     type  \
# 0                     name   object
# 1             type_company   object
# 2                      lat  float64
# 3                      lon  float64
# 4                     city   object
# 5            avg_stars_num  float64
# 6            n_reviews_num  float64
# 7             encoded_user   object
# 8              local_guide  float64
# 9   clean_other_review_num  float64
# 10          published_date   object
# 11              today_date   object
# 12               stars_num  float64
# 13               review_EN   object
# 14           original_lang   object
#
#                                                             description
# 0                                                         Business name
# 1   Type of company: Trucking company, Warehouse, Shipping company, etc
# 2                                                              Latitude
# 3                                                             Longitude
# ...

# %%
#drop NaN values from reviews column
raw_reviews = df["review_EN"]
reviews = raw_reviews.dropna()
print(reviews)
# Out:
# 3       Best employer ever. Worked there for approximately 4 years. The time of my life, bringing hatching eggs to Kalecik, Turkey.\r\nNever a complaint about salary; they simply paid everything. I'm still sorry that I left, after being robbed in Austria.
# 4                                                                                                                                                                                                      better place with very good people everything is perfect
# 5                                                                                                                                                                                                                                                          Nice
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')

#lower case
reviews= reviews.str.lower()

#remove '!' and '.'
reviews = reviews.str.replace(r'!', '')
reviews = reviews.str.replace(r'.', '')

#tokenize
reviews_token = reviews.apply(word_tokenize)
reviews_token.head(10)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KA\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\KA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\KA\AppData\Local\Temp\ipykernel_17168\3953354552.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   reviews = reviews.str.replace(r'.', '')
# ...

# %%
stop_words = set(stopwords.words('english')) 

filtered_words = [word for word in reviews_token if word not in stopwords.words('english')]
print(filtered_words)
# Out:
# [['best', 'employer', 'ever', 'worked', 'there', 'for', 'approximately', '4', 'years', 'the', 'time', 'of', 'my', 'lif', 'bringing', 'hatching', 'eggs', 'to', 'kaleci', 'turkey', 'never', 'a', 'complaint', 'about', 'salary', ';', 'they', 'simply', 'paid', 'everything', 'i', "'m", 'still', 'sorry', 'that', 'i', 'lef', 'after', 'being', 'robbed', 'in', 'austria'], ['better', 'place', 'with', 'very', 'good', 'people', 'everything', 'is', 'perfect'], ['nice'], ['good', 'firm', 'the', 'staff', 'are', 'very', 'welcoming', 'and', 'friendly', 'thanks', 'for', 'the', 'positive', 'vibes'], ['top', 'compan', 'and', 'coffe', 'so', 'recommended'], ['a', 'very', 'neat', 'company', 'with', 'professional', 'people', 'who', 'know', 'what', 'they', 'are', 'doing', 'i', 'was', 'allowed', 'to', 'drive', 'there', 'for', '4', 'weeks', 'before', 'the', 'corona', 'broke', 'out', 'unfortunatel', 'mr', 'hans', 'dekkers', 'could', 'no', 'longer', 'keep', 'me', 'workin', 'think', 'back', 'with', 'melancholy', '
# ...
